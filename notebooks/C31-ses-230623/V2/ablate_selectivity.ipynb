# %%
# %cd ../../..
# Out:
# /home/eli/AnacondaProjects/surprisal_regression

# %%
import hydra
import math
import matplotlib.pyplot as plt
import numpy as np
from omegaconf import OmegaConf
import pyro
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
from src.models.components.linear_regression import TrialwiseLinearRegression
import src.eval as evaluation

# %%
with hydra.initialize(version_base="1.3", config_path="../../../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2025-03-24_20-33-43/checkpoints/last.ckpt", "data.session_path=/mnt/data/surprisal_coding/epoched/glo_mua_epoched_11.mat",
                        "data.area=V2", "model.importance.ablations=['selectivity']"], return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    _, objects = evaluation.evaluate(cfg)
# Out:
# [rank: 0] No logger configs found! Skipping...
# [striatum:1787882] shmem: mmap: an error occurred while determining whether or not /tmp/ompi.striatum.1000/jf.0/2353790976/shared_mem_cuda_pool.striatum could be created.
# [striatum:1787882] create_and_attach: unable to create shared memory BTL coordinating structure :: size 134217728
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Restoring states from the checkpoint path at logs/train/runs/2025-03-24_20-33-43/checkpoints/last.ckpt
# ...

# %%
with torch.no_grad():
    offsets = []
    originals = []
    reconstructions = []
    regressor = []
    times = []
    
    for b, (muae, regressors) in tqdm(enumerate(objects['datamodule'].test_dataloader())):
        _, predictions, _, trace = objects['model'].model_step((muae, regressors))

        offsets.append(trace.nodes['baseline']['value'].mean(dim=0))
        originals.append(muae)
        reconstructions.append(predictions.mean(dim=0))
        regressor.append(regressors)
        times.append(trace.nodes['time']['value'].mean(dim=0))

    offsets = torch.cat(offsets, dim=0)
    originals = torch.cat(originals, dim=0)
    reconstructions = torch.cat(reconstructions, dim=0)
    regressors = torch.cat(regressor, dim=0)
    times = torch.cat(times, dim=0)
# Out:
# 8it [00:00, 19.32it/s]

# %%
offsets.mean(dim=0)
# Out:
# tensor([1.3561])

# %%
(objects['model'].importance.repetition_q_loc, objects['model'].importance.repetition_q_log_scale.exp())
# Out:
# (Parameter containing:
#  tensor([-0.0120], requires_grad=True),
#  tensor([0.7225], grad_fn=<ExpBackward0>))

# %%
times.mean(dim=0)
# Out:
# tensor([-0.0804])

# %%
def lo_trials():
    return torch.isclose(regressors[:, :, 3], -torch.tensor([[1, 1, 1, 0.8]], dtype=torch.double).log2()).all(dim=-1).argwhere().flatten(0, 1)

def go_trials():
    return torch.isclose(regressors[:, :, 3], -torch.tensor([[1, 1, 1, 0.2]], dtype=torch.double).log2()).all(dim=-1).argwhere().flatten(0, 1)

def rndctrl_trials():
    return torch.isclose(regressors[:, :, 3], -torch.tensor([[0.5, 0.5, 0.5, 0.5]], dtype=torch.double).log2()).all(dim=-1).argwhere().flatten(0, 1)

def seqctrl_trials():
    return torch.isclose(regressors[:, :, 3], -torch.tensor([[1., 1., 1., 1.]], dtype=torch.double).log2()).all(dim=-1).argwhere().flatten(0, 1)

# %%
def comparison_plot(trials):
    heights = []
    all_originals = originals[trials, :].mean(dim=0)
    all_reconstructions = reconstructions[trials, :].mean(dim=0)

    for p in range(4):
        heights = heights + [all_originals[p].item(), all_reconstructions[p].item()]

    plt.bar(["P1", "P1'", "P2", "P2'", "P3", "P3'", "P4", "P4'"], heights, color=[('b', 1.), ('b', 0.4), ('b', 1.), ('b', 0.4), ('b', 1.), ('b', 0.4), ('b', 1.), ('b', 0.4)])

# %%
comparison_plot(lo_trials())

# %%
comparison_plot(go_trials())

# %%
comparison_plot(rndctrl_trials())

# %%
comparison_plot(seqctrl_trials())
